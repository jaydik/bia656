# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from itertools import product

# %%
data = pd.read_csv('postProcessed.csv')
# Out:
# /usr/lib/python2.7/dist-packages/pandas/io/parsers.py:1150: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
data.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday             DateTime  Year  Month  Day  WeekNumber
# 0              1  2015-07-31 00:00:00  2015      7   31          31
# 1              1  2015-07-31 00:00:00  2015      7   31          31
# 2              1  2015-07-31 00:00:00  2015      7   31          31
# 3              1  2015-07-31 00:00:00  2015      7   31          31
# 4              1  2015-07-31 00:00:00  2015      7   31          31

# %% [markdown]
# ## Impute values for the missing incomes

# %%
# Need to make a key for store/date combo so I can figure out the missing values
store_dates = [x for x in product(np.unique(data['Date']), np.unique(data['Store']))]

# %%
data.groupby('DayOfWeek')['Open'].describe()
# Out:
# DayOfWeek
# 1          count    144730.000000
#            mean          0.950459
#            std           0.216994
#            min           0.000000
#            25%           1.000000
#            50%           1.000000
#            75%           1.000000
#            max           1.000000
# 2          count    145664.000000
#            mean          0.988309
#            std           0.107493
#            min           0.000000
#            25%           1.000000
#            50%           1.000000
#            75%           1.000000
#            max           1.000000
# 3          count    145665.000000
#            mean          0.974400
#            std           0.157939
#            min           0.000000
#            25%           1.000000
#            50%           1.000000
#            75%           1.000000
#            max           1.000000
# 4          count    145845.000000
#            mean          0.923199
#            std           0.266276
# ...
